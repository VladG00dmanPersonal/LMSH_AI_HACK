# %%
import pandas as pd
import numpy as np

from catboost import CatBoostRegressor

import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import trange
from tqdm.cli import tqdm

# %% [markdown]
# ## prepocessing

# %%
df_belchonok = pd.read_csv('./preprocessed_data/belchonok.csv')
df_future = pd.read_csv('./preprocessed_data/future.csv')
df_granit = pd.read_csv('./preprocessed_data/granit_nauki.csv')
df_innopolis = pd.read_csv('./preprocessed_data/innopolis.csv')
df_itmo = pd.read_csv('./preprocessed_data/itmo.csv')
df_mosh = pd.read_csv('./preprocessed_data/mosh.csv')
df_open = pd.read_csv('./preprocessed_data/open.csv')
df_vuz = pd.read_csv('./preprocessed_data/vuz_akadem.csv')
df_mow_sch = pd.read_csv('./preprocessed_data/MOW_SCH.csv')
df_mow_mun = pd.read_csv('./preprocessed_data/MOW_MUN.csv')
df_reg = pd.read_csv('./preprocessed_data/reg.csv')
df_arso_fin = pd.read_csv('./preprocessed_data/fin.csv')

# %% [markdown]
# ### Фильтрация по участникам

# %%
df_arso_fin = df_arso_fin.sort_values(by=['year', 'score'], ascending=[True, False])
df_arso_fin.head()
# Out:
#    place         name                region  class_study   p1   p2   p3  p4  \
# 0      1   Грекова Д.                Москва           11  100  100  100  70
# 1      2  Абдуллин Г.  Республика Татарстан           11  100  100  100  70
# 2      3   Жиганов В.                Москва           10  100  100   88  60
# 3      4   Звездин В.       Санкт-Петербург           10  100  100  100  70
# 4      5    Иванов Н.                Москва           11  100  100   88  65
#
#     p5   p6  p7  p8  score title   year
# 0  100   88  86  80    724     1  24-25
# 1  100  100  70  80    720     1  24-25
# 2  100  100  66  68    682     1  24-25
# 3  100   76  66  64    676     1  24-25
# 4  100  100  65  50    668     1  24-25

# %% [markdown]
# #### Проблема с совпадением фамилия + первая буква имени

# %%
names = df_arso_fin['name'].value_counts().keys().to_numpy()

# %%
names[df_arso_fin['name'].value_counts() > 2]
# Out:
# array(['Макаров М.', 'Закиров А.', 'Торба А.', 'Андреев А.', 'Осипов Д.',
#        'Зайцев А.', 'Соколов М.'], dtype=object)

# %%
df_arso_fin['name'].value_counts()
# Out:
# name
# Макаров М.       4
# Закиров А.       4
# Торба А.         3
# Андреев А.       3
# Осипов Д.        3
#                 ..
# Виноградов П.    1
# Зуева А.         1
# Кочуров Е.       1
# Курзин И.        1
# Яковлева П.      1
# Name: count, Length: 719, dtype: int64

# %%
df_arso_fin[df_arso_fin['name'].isin(names[df_arso_fin['name'].value_counts() > 2])].sort_values(by=['place'], ascending=[True])
# Out:
#      place        name                region  class_study   p1   p2  p3  p4  \
# 505     13  Макаров М.                Москва           11  100  100  26  40
# 508     16  Макаров М.                Москва           11  100  100  20  31
# 28      29  Макаров М.                Москва           10  100  100  63   0
# 528     35  Закиров А.  Республика Татарстан           10  100  100  26  35
# 41      41  Закиров А.  Республика Татарстан            9  100  100  63  44
# 534     42  Закиров А.  Республика Татарстан           11  100  100  20  32
# 98      99    Торба А.                Москва           10  100   86  49  30
# 107    108  Закиров А.  Республика Татарстан           10  100  100  51  16
# 604    111    Торба А.                Москва           11  100   46  26  41
# 606    113  Андреев А.    Ростовская область           11  100   51  26  35
# 148    148  Макаров М.                Москва           10  100  100   0  37
# 702    209   Зайцев А.      Липецкая область           10  100   55   0  21
# 704    209   Осипов Д.  Республика Татарстан           11  100  100  20   0
# 212    213  Андреев А.      Липецкая область            9  100   64   9  24
# 718    226  Андреев А.      Липецкая область           10  100   24  20  18
# 738    245  Соколов М.       Санкт-Петербург           10  100    9  20  23
# 253    254   Осипов Д.                Москва           11  100    0  65  16
# 801    308   Зайцев А.  Республика Татарстан           10  100   14  20  13
# 307    308   Зайцев А.      Липецкая область            9  100    5   9  30
# 326    326  Соколов М.       Санкт-Петербург            9  100   11  16   0
# 341    342   Осипов Д.  Республика Татарстан           10  100    0   0  16
# 946    454  Соколов М.                Москва            9  100   35  20  21
# 953    460    Торба А.                Москва            8  100   20  13  17
#
#       p5   p6   p7  p8  score title   year
# 505  100  100   89  34    589   1.0  25-26
# 508  100   95  100  25    571   1.0  25-26
# 28   100  100   65  60    588     1  24-25
# 528  100   85   59  32    537   1.0  25-26
# 41   100   71   55  33    566     2  24-25
# 534  100   85   59  34    530   2.0  25-26
# 98   100   66   40  46    517     2  24-25
# 107  100   76   50  17    510     2  24-25
# 604  100   85   59  25    482   2.0  25-26
# 606  100   85   59  25    481   2.0  25-26
# 148  100  100    0  46    483     2  24-25
# 702  100   85   59  16    436   2.0  25-26
# 704  100   85   23   8    436   2.0  25-26
# 212  100   83   46  21    447     2  24-25
# 718  100   85   59  25    431   2.0  25-26
# 738  100   85   59  27    423   NaN  25-26
# 253  100   71   50  13    415    \n  24-25
# 801  100   85   48   6    386   NaN  25-26
# 307  100   74   22  36    376    \n  24-25
# 326  100   88   43   0    358    \n  24-25
# 341  100  100   33   0    349    \n  24-25
# 946   25   15   35   6    257   NaN  25-26
# 953   25   40   10   6    231   NaN  25-26

# %% [markdown]
# **РЕШЕНИЕ**:
# ликвидация

# %%
names2drop = names[df_arso_fin['name'].value_counts() > 2]

df_arso_fin = df_arso_fin[~df_arso_fin['name'].isin(names2drop)]
df_arso_fin.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 names2drop = names[df_arso_fin['name'].value_counts() > 2]
#       2
# ----> 3 df_arso_fin = df_arso_fin.drop(columns=['region']).groupby('name', as_index=False).mean()
#       4 df_arso_fin
#
# File ~/.conda/envs/neuralbase/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.conda/envs/neuralbase/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File ~/.conda/envs/neuralbase/lib/python3.12/site-packages/pandas/core/internals/managers.py:1654, in BlockManager.grouped_reduce(self, func)
#    1652             result_blocks = extend_blocks(applied, result_blocks)
#    1653     else:
# -> 1654         applied = blk.apply(func)
#    1655         result_blocks = extend_blocks(applied, result_blocks)
#    1657 if len(result_blocks) == 0:
#
# File ~/.conda/envs/neuralbase/lib/python3.12/site-packages/pandas/core/internals/blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File ~/.conda/envs/neuralbase/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~/.conda/envs/neuralbase/lib/python3.12/site-packages/pandas/core/groupby/ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File ~/.conda/envs/neuralbase/lib/python3.12/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File ~/.conda/envs/neuralbase/lib/python3.12/site-packages/pandas/core/arrays/base.py:2808, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2794 if isinstance(self.dtype, StringDtype):
#    2795     # StringArray
#    2796     if op.how in [
#    2797         "prod",
#    2798         "mean",
#    (...)   2806         "kurt",
#    2807     ]:
# -> 2808         raise TypeError(
#    2809             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2810         )
#    2811     if op.how not in ["any", "all"]:
#    2812         # Fail early to avoid conversion to object
#    2813         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'
