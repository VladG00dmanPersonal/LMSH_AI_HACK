# %%
import pandas as pd
import numpy as np
import os

# %%
FIN = open('./raw/FIN')

# %%
FIN
# Out:
# <_io.TextIOWrapper name='./raw/FIN' mode='r' encoding='UTF-8'>

# %%
def format(file) -> pd.DataFrame:
    file.seek(0)

    id = []
    surname = []
    name = []
    father_name = []
    region = []
    class_study = []
    p = []
    title = []

    for line in file:
        line = line.split(' ')
        for i in range(len(line)):
            line[i] = line[i].split('\t')
        tmp = line
        line = []
        for t in tmp:
            line.extend(t)
        # print(line)

        id.append(line[0])
        surname.append(line[1])
        name.append(line[2])
        father_name.append(line[3])

        i = 0
        a = line[4]
        while not line[4 + i].endswith(','):
            i += 1
            a = a + ' ' + line[4 + i]
        a = a.replace('(', '')
        a = a.replace(',', '')
        region.append(a)

        class_study.append(line[5 + i])
        a = line[(i + 7) : (i + 16)]
        for i in range(9):
            if a[i] == '.':
                a[i] = 0
            a[i] = (int)(a[i])
        p.append(a)

        if 15 + i < len(line):
            title.append(line[16 + i])
        else:
            title.append(None)

        # print(id[-1], surname[-1], name[-1], father_name[-1], region[-1], class_study[-1], *p[-1])
    
    df = pd.DataFrame({
        'id': id,
        'surname': surname,
        'name': name,
        'father_name': father_name,
        'region': region,
        'class_study': class_study,
        'p1': [i[0] for i in p],
        'p2': [i[1] for i in p],
        'p3': [i[2] for i in p],
        'p4': [i[3] for i in p],
        'p5': [i[4] for i in p],
        'p6': [i[5] for i in p],
        'p7': [i[6] for i in p],
        'p8': [i[7] for i in p],
        'score': [i[8] for i in p],
        'title': title
    })
    return df

format(FIN)
# Out:
#       id    surname       name    father_name                     region  \
# 0      1    Звездин   Владимир      Сергеевич            Санкт-Петербург
# 1      2   Кузнецов    Евгений      Сергеевич           Липецкая область
# 2      3  Приводнов       Марк      Сергеевич                     Москва
# 3      4    Жиганов  Владислав  Александрович                     Москва
# 4      5  Кравченко     Максим        Юрьевич                     Москва
# ..   ...        ...        ...            ...                        ...
# 481  482      Зуева      Алина      Ильинична            Камчатский край
# 482  483    Кочуров       Егор      Андреевич          Кировская область
# 483  484      Голов     Сергей     Евгеньевич        Республика Мордовия
# 484  485     Курзин      Игорь  Александрович        Ульяновская область
# 485  486   Яковлева     Полина      Сергеевна  Ненецкий автономный округ
#
#     class_study   p1   p2  p3   p4   p5   p6   p7  p8  score title
# 0            11  100  100  58  100  100  100  100  74    732  None
# 1            10  100  100  98   54  100   95  100  64    711  None
# 2            10  100  100  95   58  100  100   77  80    710  None
# 3            11  100  100  90   64  100  100   59  67    680  None
# 4            10  100  100  57   47  100  100  100  67    671  None
# ..          ...  ...  ...  ..  ...  ...  ...  ...  ..    ...   ...
# 481          11  100   11  13    0    0   15    0   6    145  None
# 482          10   42    9  20   13   36    0   10   0    130  None
# 483          11  100    9   0    0    0   15    0   0    124  None
# 484           9   36    9  13    0   36   10   10   6    120  None
# 485           9   42    0   0    0    0    0    0   0     42  None
#
# [486 rows x 16 columns]
